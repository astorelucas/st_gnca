# %%
# xLSTM para previsão de tráfego com dataset PEMS03

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import sklearn

# %%
# xLSTM aplicado ao dataset PEMS03

# Este script usa o repositório [NX-AI/xlstm](https://github.com/NX-AI/xlstm) como base para aplicar um modelo xLSTM na tarefa de previsão de tráfego com o dataset PEMS03.

## 🧩 Pré-requisitos
# %pip install xlstm mlstm_kernels  # Install specialized LSTM packages
# Out:
# Requirement already satisfied: xlstm in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (2.0.4)
# Requirement already satisfied: mlstm_kernels in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (2.0.1)
# Requirement already satisfied: torch in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (2.7.1)
# Requirement already satisfied: einops in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (0.8.1)
# Requirement already satisfied: numpy in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (2.3.1)
# Requirement already satisfied: opt_einsum in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (3.4.0)
# Requirement already satisfied: omegaconf in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (2.3.0)
# Requirement already satisfied: transformers in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (4.54.1)
# Requirement already satisfied: reportlab in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (4.4.3)
# Requirement already satisfied: joypy in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (0.2.6)
# Requirement already satisfied: ipykernel in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (6.29.5)
# Requirement already satisfied: dacite in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (1.9.2)
# Requirement already satisfied: ftfy in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (6.3.1)
# Requirement already satisfied: ninja in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (1.11.1.4)
# Requirement already satisfied: huggingface-hub in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (0.34.3)
# Requirement already satisfied: rich in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (14.1.0)
# Requirement already satisfied: tokenizers in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (0.21.4)
# Requirement already satisfied: tqdm in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (4.67.1)
# Requirement already satisfied: seaborn in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from xlstm) (0.13.2)
# Requirement already satisfied: matplotlib in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from mlstm_kernels) (3.10.3)
# Requirement already satisfied: wcwidth in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ftfy->xlstm) (0.2.13)
# Requirement already satisfied: filelock in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from huggingface-hub->xlstm) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from huggingface-hub->xlstm) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from huggingface-hub->xlstm) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from huggingface-hub->xlstm) (6.0.2)
# Requirement already satisfied: requests in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from huggingface-hub->xlstm) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from huggingface-hub->xlstm) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from huggingface-hub->xlstm) (1.1.5)
# Requirement already satisfied: appnope in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (9.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (1.6.0)
# Requirement already satisfied: psutil in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipykernel->xlstm) (5.14.3)
# Requirement already satisfied: decorator in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->xlstm) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->xlstm) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->xlstm) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->xlstm) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->xlstm) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->xlstm) (2.19.2)
# Requirement already satisfied: stack_data in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->xlstm) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->xlstm) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from jupyter-client>=6.1.12->ipykernel->xlstm) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->xlstm) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->xlstm) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->xlstm) (1.17.0)
# Requirement already satisfied: scipy>=0.11.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from joypy->xlstm) (1.16.0)
# Requirement already satisfied: pandas>=0.20.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from joypy->xlstm) (2.3.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from pandas>=0.20.0->joypy->xlstm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from pandas>=0.20.0->joypy->xlstm) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from matplotlib->mlstm_kernels) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from matplotlib->mlstm_kernels) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from matplotlib->mlstm_kernels) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from matplotlib->mlstm_kernels) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from matplotlib->mlstm_kernels) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from matplotlib->mlstm_kernels) (3.2.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from omegaconf->xlstm) (4.9.3)
# Requirement already satisfied: charset-normalizer in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from reportlab->xlstm) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from requests->huggingface-hub->xlstm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from requests->huggingface-hub->xlstm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from requests->huggingface-hub->xlstm) (2025.7.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from rich->xlstm) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->xlstm) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->xlstm) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->xlstm) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->xlstm) (0.2.3)
# Requirement already satisfied: setuptools in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from torch->xlstm) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from torch->xlstm) (1.14.0)
# Requirement already satisfied: networkx in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from torch->xlstm) (3.5)
# Requirement already satisfied: jinja2 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from torch->xlstm) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch->xlstm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from jinja2->torch->xlstm) (3.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from transformers->xlstm) (2025.7.34)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/lucasastore/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages (from transformers->xlstm) (0.5.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
## 📥 1. Carregar e preparar o dataset PEMS03

import numpy as np
from sklearn.preprocessing import StandardScaler
import torch
from torch.utils.data import Dataset, DataLoader

path = 'PEMS03.npz'
data = np.load(path)['data']  # (num_samples, num_nodes, num_features)
data = data[:, :, 0]  # Seleciona só volume (shape: num_samples x num_nodes)

scaler = StandardScaler()
data = scaler.fit_transform(data)

def create_sequences(data, input_len, output_len):
    X, Y = [], []
    for i in range(len(data) - input_len - output_len):
        x = data[i:i+input_len]
        y = data[i+input_len:i+input_len+output_len]
        X.append(x)
        Y.append(y)
    return np.stack(X), np.stack(Y)

input_len = 12
output_len = 3
X, Y = create_sequences(data, input_len, output_len)  # shape: (N, input_len, num_nodes), (N, output_len, num_nodes)

train_end = int(len(X) * 0.6)
val_end = int(len(X) * 0.8)

X_train, Y_train = X[:train_end], Y[:train_end]
X_val, Y_val = X[train_end:val_end], Y[train_end:val_end]
X_test, Y_test = X[val_end:], Y[val_end:]

class TrafficDataset(Dataset):
    def __init__(self, X, Y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.Y = torch.tensor(Y, dtype=torch.float32)
    def __len__(self): return len(self.X)
    def __getitem__(self, idx): return self.X[idx], self.Y[idx]

batch_size = 64
train_loader = DataLoader(TrafficDataset(X_train, Y_train), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(TrafficDataset(X_val, Y_val), batch_size=batch_size)
test_loader = DataLoader(TrafficDataset(X_test, Y_test), batch_size=batch_size)

# %%
## 🧠 2. Construir o modelo xLSTM

import torch.nn as nn
from xLSTM import xLSTMBlockStack, xLSTMBlockStackConfig, sLSTMBlockConfig, mLSTMBlockConfig, sLSTMLayerConfig, mLSTMLayerConfig, FeedForwardConfig

num_nodes = X.shape[2]
print(num_nodes)
hidden_dim = 128

cfg = xLSTMBlockStackConfig(
    mlstm_block=mLSTMBlockConfig(
        mlstm=mLSTMLayerConfig(conv1d_kernel_size=3, num_heads=4)
    ),
    slstm_block=sLSTMBlockConfig(
        slstm=sLSTMLayerConfig(backend="cuda", num_heads=2, conv1d_kernel_size=3),
        feedforward=FeedForwardConfig(proj_factor=1.0, act_fn="gelu")
    ),
    context_length=input_len,
    num_blocks=3,
    embedding_dim=hidden_dim,
    slstm_at=[1]
)

class xLSTMForecast(nn.Module):
    def __init__(self):
        super().__init__()
        self.input_proj = nn.Linear(num_nodes, hidden_dim)
        self.xlstm = xLSTMBlockStack(cfg)
        self.output_proj = nn.Linear(hidden_dim, num_nodes * output_len)

    def forward(self, x):
        # x: (B, T, N)
        x = self.input_proj(x)  # -> (B, T, H)
        x = self.xlstm(x)       # -> (B, T, H)
        x = x[:, -1, :]         # pega último passo
        x = self.output_proj(x) # -> (B, N * output_len)
        return x.view(-1, output_len, num_nodes)  # -> (B, output_len, N)

model = xLSTMForecast()
# Out:
# 358
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 39
#      36         x = self.output_proj(x) # -> (B, N * output_len)
#      37         return x.view(-1, output_len, num_nodes)  # -> (B, output_len, N)
# ---> 39 model = xLSTMForecast().cpu()
#
# Cell In[18], line 28, in xLSTMForecast.__init__(self)
#      26 super().__init__()
#      27 self.input_proj = nn.Linear(num_nodes, hidden_dim)
# ---> 28 self.xlstm = xLSTMBlockStack(cfg)
#      29 self.output_proj = nn.Linear(hidden_dim, num_nodes * output_len)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/xlstm_block_stack.py:84, in xLSTMBlockStack.__init__(self, config)
#      81 super().__init__()
#      82 self.config = config
# ---> 84 self.blocks = self._create_blocks(config=config)
#      85 if config.add_post_blocks_norm:
#      86     self.post_blocks_norm = LayerNorm(ndim=config.embedding_dim)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/xlstm_block_stack.py:105, in xLSTMBlockStack._create_blocks(self, config)
#     103         config._block_idx = block_idx
#     104         config.__post_init__()
# --> 105     blocks.append(sLSTMBlock(config=config))
#     106 else:
#     107     raise ValueError(f"Invalid block type {block_type_int}")
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/slstm/block.py:33, in sLSTMBlock.__init__(self, config)
#      32 def __init__(self, config: sLSTMBlockConfig):
# ---> 33     super().__init__(
#      34         xLSTMBlockConfig(
#      35             mlstm=None,
#      36             slstm=config.slstm,
#      37             feedforward=config.feedforward,
#      38             _block_idx=config._block_idx,
#      39             _num_blocks=config._num_blocks,
#      40         )
#      41     )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/xlstm_block.py:63, in xLSTMBlock.__init__(self, config)
#      61     self.xlstm = mLSTMLayer(config=self.config.mlstm)
#      62 elif self.config.slstm is not None:
# ---> 63     self.xlstm = sLSTMLayer(config=self.config.slstm)
#      64 else:
#      65     raise ValueError("Either mlstm or slstm must be provided")
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/slstm/layer.py:78, in sLSTMLayer.__init__(self, config)
#      63 self.zgate = LinearHeadwiseExpand(
#      64     config=LinearHeadwiseExpandConfig(
#      65         in_features=self.config.embedding_dim,
#    (...)     68     )
#      69 )
#      70 self.ogate = LinearHeadwiseExpand(
#      71     config=LinearHeadwiseExpandConfig(
#      72         in_features=self.config.embedding_dim,
#    (...)     75     )
#      76 )
# ---> 78 self.slstm_cell = sLSTMCell(self.config)
#      79 self.group_norm = MultiHeadLayerNorm(
#      80     ndim=self.config.embedding_dim, weight=self.config.group_norm_weight
#      81 )
#      82 self.dropout = nn.Dropout(self.config.dropout)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/slstm/cell.py:780, in sLSTMCell.__new__(cls, config, skip_backend_init)
#     778 def __new__(cls, config: sLSTMCellConfig, skip_backend_init: bool = False):
#     779     if config.backend == "cuda":
# --> 780         return sLSTMCell_cuda(config, skip_backend_init=skip_backend_init)
#     781     elif config.backend == "vanilla":
#     782         return sLSTMCell_vanilla(config)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/slstm/cell.py:690, in sLSTMCell_cuda.__init__(self, config, skip_backend_init)
#     688 self.internal_input_shape = "SBNGH"
#     689 if not skip_backend_init:
# --> 690     self.func = sLSTMCellFuncGenerator(self.training, config)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/slstm/cell.py:536, in sLSTMCellFuncGenerator(training, config)
#     535 def sLSTMCellFuncGenerator(training, config: sLSTMCellConfig):
# --> 536     slstm_cuda = sLSTMCellCUDA.instance(config=config)
#     537     slstm_mod = slstm_cuda.sLSTMFunc(
#     538         training, config.batch_size, config.hidden_size, config.num_heads
#     539     )
#     541     class sLSTMCellFunction(torch.autograd.Function):
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/slstm/cell.py:515, in sLSTMCellCUDA.instance(cls, config)
#     512 @classmethod
#     513 def instance(cls, config: sLSTMCellConfig):
#     514     if repr(config) not in cls.mod:
# --> 515         cls.mod[repr(config)] = load(
#     516             name=config.function,
#     517             sources=[
#     518                 str(curdir / "src" / "cuda" / "slstm.cc"),
#     519                 str(curdir / "src" / "cuda" / "slstm_forward.cu"),
#     520                 str(curdir / "src" / "cuda" / "slstm_backward.cu"),
#     521                 str(curdir / "src" / "cuda" / "slstm_backward_cut.cu"),
#     522                 str(curdir / "src" / "cuda" / f"{config.function}_pointwise.cu"),
#     523                 str(curdir / "src" / "util" / "blas.cu"),
#     524                 str(curdir / "src" / "util" / "cuda_error.cu"),
#     525             ],
#     526             extra_cflags=[
#     527                 f"-D{const}={constval}"
#     528                 for const, constval in config.constants.items()
#     529             ]
#     530             + config.defines,
#     531         )
#     532     return cls.mod[repr(config)]
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Doutorado/DCC UFMG/Neural Network Cellular Automata/st_gnca/.venv/lib/python3.13/site-packages/xLSTM/blocks/slstm/src/cuda_init.py:92, in load(name, sources, extra_cflags, extra_cuda_cflags, **kwargs)
#      86     extra_cflags.append("-isystem")
#      87     extra_cflags.append(eip)
#      89 myargs = {
#      90     "verbose": True,
#      91     "with_cuda": True,
# ---> 92     "extra_ldflags": [f"-L{os.environ['CUDA_LIB']}", "-lcublas"],
#      93     "extra_cflags": [*extra_cflags],
#      94     "extra_cuda_cflags": [
#      95         # "-gencode",
#      96         # "arch=compute_70,code=compute_70",
#      97         # "-dbg=1",
#      98         '-Xptxas="-v"',
#      99         "-gencode",
#     100         "arch=compute_80,code=compute_80",
#     101         "-res-usage",
#     102         "--use_fast_math",
#     103         "-O3",
#     104         "-Xptxas -O3",
#     105         "--extra-device-vectorization",
#     106         *extra_cflags,
#     107         *extra_cuda_cflags,
#     108     ],
#     109 }
#     110 print(myargs)
#     111 myargs.update(**kwargs)
#
# File <frozen os>:717, in __getitem__(self, key)
#
# KeyError: 'CUDA_LIB'

# %%
## 🏋️ 3. Treinamento

import torch.optim as optim
import matplotlib.pyplot as plt

epochs = 50
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

def train_epoch():
    model.train()
    total_loss = 0
    for X_batch, Y_batch in train_loader:
        X_batch, Y_batch = X_batch.cuda(), Y_batch.cuda()
        optimizer.zero_grad()
        pred = model(X_batch)
        loss = criterion(pred, Y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

def val_epoch():
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for X_batch, Y_batch in val_loader:
            X_batch, Y_batch = X_batch.cuda(), Y_batch.cuda()
            pred = model(X_batch)
            loss = criterion(pred, Y_batch)
            total_loss += loss.item()
    return total_loss / len(val_loader)

train_losses, val_losses = [], []

for epoch in range(epochs):
    train_loss = train_epoch()
    val_loss = val_epoch()
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

plt.plot(train_losses, label='Train')
plt.plot(val_losses, label='Validation')
plt.legend()
plt.title("Loss por época")
plt.xlabel("Épocas")
plt.ylabel("MSE")
plt.show()

# %%
## 🧪 4. Avaliação Final
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

def evaluate(loader):
    model.eval()
    preds, trues = [], []
    with torch.no_grad():
        for X_batch, Y_batch in loader:
            X_batch = X_batch.cuda()
            pred = model(X_batch).cpu().numpy()
            preds.append(pred)
            trues.append(Y_batch.numpy())
    preds = np.concatenate(preds)
    trues = np.concatenate(trues)
    mae = mean_absolute_error(trues.flatten(), preds.flatten())
    rmse = mean_squared_error(trues.flatten(), preds.flatten())
    return mae, rmse

mae, rmse = evaluate(test_loader)
print(f"Test MAE: {mae:.4f}, RMSE: {rmse:.4f}")
